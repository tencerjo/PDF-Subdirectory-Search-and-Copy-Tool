# %%
# no libraries need to be installed

# %%
# v0.5
# pdf folder below given directory
# adds files by date modified, use this to sort

import os
import shutil

def sort_files_by_modification_date(files):
    # Function to sort files by modification date in descending order
    return sorted(files, key=lambda x: os.path.getmtime(x), reverse=True)

def search_pdfs_and_create_folder(main_directory):
    try:
        # Validate if main_directory exists
        if not os.path.exists(main_directory):
            raise FileNotFoundError(f"The directory '{main_directory}' does not exist.")

        # Determine if the path is a network path
        if os.path.isdir(main_directory) and main_directory.startswith('\\\\'):
            raise OSError(f"Network path '{main_directory}' not supported for folder creation.")

        # Create the new folder name
        new_folder_name = f"All Reports {os.path.basename(main_directory)}"
        new_folder_path = os.path.join(main_directory, new_folder_name)

        # Create the new folder if it doesn't exist
        if not os.path.exists(new_folder_path):
            os.makedirs(new_folder_path)
        else:
            print(f"The folder '{new_folder_path}' already exists.")

        # Search for PDFs in subdirectories and sort them by modification date
        for root, dirs, files in os.walk(main_directory):
            pdf_files = [os.path.join(root, file) for file in files if file.lower().endswith(".pdf")]
            pdf_files_sorted = sort_files_by_modification_date(pdf_files)

            # Copy PDF files to the new folder
            for file in pdf_files_sorted:
                src_path = file
                dst_path = os.path.join(new_folder_path, os.path.basename(file))
                try:
                    shutil.copy2(src_path, dst_path)
                    print(f"Copied '{os.path.basename(file)}' to '{new_folder_path}'")
                except FileNotFoundError:
                    print(f"File '{os.path.basename(file)}' not found.")

        print(f"All PDF files have been copied to '{new_folder_path}'")

    except FileNotFoundError as e:
        print(f"Error: {e}")
    except OSError as e:
        print(f"Error: {e}")

# Example usage
if __name__ == "__main__":
    main_directory = input("Enter the main directory path: ")
    search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35
# Copied '2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35_003-0101.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35\All Reports 2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35'
# Copied '2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35_1FE-0201.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35\All Reports 2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35'
# Error: 'C:\\Users\\JoelTencer\\Documents\\Agilent HPLC 2\\SEC\\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35\\All Reports 2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35\\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35_1FE-0201.pdf' and 'C:\\Users\\JoelTencer\\Documents\\Agilent HPLC 2\\SEC\\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35\\All Reports 2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35\\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35_1FE-0201.pdf' are the same file

# %%
# v 0.4

import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Function to sort files by modification date in descending order
    def sort_by_modification_date(files):
        return sorted(files, key=lambda x: os.path.getmtime(x), reverse=True)

    try:
        # Validate if main_directory exists
        if not os.path.exists(main_directory):
            raise FileNotFoundError(f"The directory '{main_directory}' does not exist.")

        # Determine if the path is a network path
        if os.path.isdir(main_directory) and main_directory.startswith('\\\\'):
            raise OSError(f"Network path '{main_directory}' not supported for folder creation.")

        # Create the new folder name
        new_folder_name = f"All Reports {os.path.basename(main_directory)}"
        new_folder_path = os.path.join(main_directory, new_folder_name)

        # Create the new folder if it doesn't exist
        if not os.path.exists(new_folder_path):
            os.makedirs(new_folder_path)
        else:
            print(f"The folder '{new_folder_path}' already exists.")

        # Search for PDFs in subdirectories and sort them by modification date
        for root, dirs, files in os.walk(main_directory):
            pdf_files = [os.path.join(root, file) for file in files if file.lower().endswith(".pdf")]
            pdf_files_sorted = sort_by_modification_date(pdf_files)

            # Copy PDF files to the new folder
            for file in pdf_files_sorted:
                src_path = file
                dst_path = os.path.join(new_folder_path, os.path.basename(file))
                try:
                    shutil.copy2(src_path, dst_path)
                    print(f"Copied '{os.path.basename(file)}' to '{new_folder_path}'")
                except FileNotFoundError:
                    print(f"File '{os.path.basename(file)}' not found.")

        print(f"All PDF files have been copied to '{new_folder_path}'")

    except FileNotFoundError as e:
        print(f"Error: {e}")
    except OSError as e:
        print(f"Error: {e}")

# Example usage
if __name__ == "__main__":
    main_directory = input("Enter the main directory path: ")
    search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35
# Copied '2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35_003-0101.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35\All Reports 2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35'
# Copied '2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35_1FE-0201.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35\All Reports 2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35'
# Error: 'C:\\Users\\JoelTencer\\Documents\\Agilent HPLC 2\\SEC\\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35\\All Reports 2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35\\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35_1FE-0201.pdf' and 'C:\\Users\\JoelTencer\\Documents\\Agilent HPLC 2\\SEC\\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35\\All Reports 2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35\\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35_1FE-0201.pdf' are the same file

# %%
# v 0.3
# Sort pdfs by date modified to get them in order

import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Function to sort files by modification date in descending order
    def sort_by_modification_date(files):
        return sorted(files, key=lambda x: os.path.getmtime(x), reverse=True)

    # Create the new folder name
    new_folder_name = f"All Reports {os.path.basename(main_directory)}"
    new_folder_path = os.path.join(os.path.dirname(main_directory), new_folder_name)

    # Create the new folder if it doesn't exist
    if not os.path.exists(new_folder_path):
        os.makedirs(new_folder_path)
    else:
        print(f"The folder '{new_folder_path}' already exists.")

    # Search for PDFs in subdirectories and sort them by modification date
    for root, dirs, files in os.walk(main_directory):
        pdf_files = [os.path.join(root, file) for file in files if file.lower().endswith(".pdf")]
        pdf_files_sorted = sort_by_modification_date(pdf_files)

        # Copy PDF files to the new folder
        for file in pdf_files_sorted:
            src_path = file
            dst_path = os.path.join(new_folder_path, os.path.basename(file))
            try:
                shutil.copy2(src_path, dst_path)
                print(f"Copied '{os.path.basename(file)}' to '{new_folder_path}'")
            except FileNotFoundError:
                print(f"File '{os.path.basename(file)}' not found.")

    print(f"All PDF files have been copied to '{new_folder_path}'")

# Example usage
if __name__ == "__main__":
    main_directory = input("Enter the main directory path: ")
    search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35
# Copied '2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35_003-0101.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35'
# Copied '2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35_1FE-0201.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35'
# All PDF files have been copied to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 05 08 821 SYM BAB 4C12 FC 1C10 2024-05-09 14-50-35'

# %%
# v0.2 
# Added sort by last 4 digits so files are copied in order

import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Function to extract the last 4 digits from a filename
    def get_last_four_digits(filename):
        return int(filename[-8:-4])  # Assuming the last 4 digits are at the end of the filename
    
    # Function to sort files by the last 4 digits in descending order
    def sort_by_last_four_digits(files):
        return sorted(files, key=lambda x: get_last_four_digits(x), reverse=True)

    # Create the new folder name
    new_folder_name = f"All Reports {os.path.basename(main_directory)}"
    new_folder_path = os.path.join(os.path.dirname(main_directory), new_folder_name)

    # Create the new folder if it doesn't exist
    if not os.path.exists(new_folder_path):
        os.makedirs(new_folder_path)
    else:
        print(f"The folder '{new_folder_path}' already exists.")

    # Search for PDFs in subdirectories and sort them by the last 4 digits
    for root, dirs, files in os.walk(main_directory):
        pdf_files = [file for file in files if file.lower().endswith(".pdf")]
        pdf_files_sorted = sort_by_last_four_digits(pdf_files)

        # Copy PDF files to the new folder
        for file in pdf_files_sorted:
            src_path = os.path.join(root, file)
            dst_path = os.path.join(new_folder_path, file)
            try:
                shutil.copy2(src_path, dst_path)
                print(f"Copied '{file}' to '{new_folder_path}'")
            except FileNotFoundError:
                print(f"File '{file}' not found.")

    print(f"All PDF files have been copied to '{new_folder_path}'")

# Example usage
if __name__ == "__main__":
    main_directory = input("Enter the main directory path: ")
    search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0101.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0201.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0301.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-2601.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-4001.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AA-1101.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AB-1801.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AC-2401.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AE-3301.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AG-4601.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AH-5401.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AI-1001.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BA-1201.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BB-1901.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BC-2501.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BE-3401.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BF-3801.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BG-4701.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BH-5501.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BI-6201.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CA-1301.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CB-0401.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CC-2701.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CD-2801.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CE-0601.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CF-3901.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CG-4801.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CH-5601.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DA-1401.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DB-2001.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DD-2901.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DE-0701.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DF-4101.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DG-4901.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DH-5701.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EA-1501.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EB-2101.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1ED-3001.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EE-3501.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EF-4201.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EG-5001.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EH-5801.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FA-1601.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FB-2201.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FD-3101.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FE-3601.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FF-4301.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FG-5101.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FH-5901.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GA-1701.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GB-0801.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GD-3201.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GE-0901.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GF-4401.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GG-5201.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GH-6001.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HB-2301.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HD-0501.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HE-3701.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HF-4501.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HG-5301.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# Copied '2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HH-6101.pdf' to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'
# All PDF files have been copied to 'C:\Users\JoelTencer\Documents\Agilent HPLC 2\SEC\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10'

# %%
# unable to make work on network drive, possibly a security feature

import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    if os.name == 'nt' and not main_directory.startswith('\\\\'):
        main_directory = os.path.abspath(main_directory)
        if not main_directory.startswith('\\\\?\\'):
            main_directory = '\\\\?\\' + main_directory
    
    print(f"Main directory: {main_directory}")
    
    main_dir_name = os.path.basename(main_directory)
    new_folder_name = f"All Reports {main_dir_name}"
    new_folder_path = os.path.join(main_directory, new_folder_name)
    
    print(f"New folder path: {new_folder_path}")
    
    try:
        os.makedirs(new_folder_path, exist_ok=True)
        print(f"Created folder: {new_folder_path}")
    except OSError as e:
        print(f"Error creating folder: {new_folder_path} - {e}")
        return
    
    copied_count = 0
    
    for root, dirs, files in os.walk(main_directory):
        for file in files:
            if file.endswith(".pdf"):
                src_path = os.path.join(root, file)
                dst_path = os.path.join(new_folder_path, file)
                
                print(f"Copying from {src_path} to {dst_path}")
                
                try:
                    shutil.copy2(src_path, dst_path)
                    print(f"Copied {file}")
                    copied_count += 1
                except FileNotFoundError:
                    print(f"File {file} not found.")
                except Exception as e:
                    print(f"Error copying {file}: {e}")
    
    print(f"Successfully copied {copied_count} PDF files to {new_folder_path}")

# Example usage
main_directory = input("Enter the main directory path: ")
search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10
# Main directory: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10
# New folder path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10
# Created folder: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\003-0101.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0101.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0101.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0101.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\003-0201.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0201.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0201.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\003-0301.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0301.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0301.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0301.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\003-2601.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-2601.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-2601.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-2601.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\003-4001.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-4001.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-4001.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-4001.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AA-1101.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AA-1101.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AA-1101.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AA-1101.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AB-1801.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AB-1801.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AB-1801.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AB-1801.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AC-2401.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AC-2401.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AC-2401.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AC-2401.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AE-3301.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AE-3301.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AE-3301.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AE-3301.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AG-4601.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AG-4601.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AG-4601.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AG-4601.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AH-5401.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AH-5401.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AH-5401.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AH-5401.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1AI-1001.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AI-1001.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AI-1001.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AI-1001.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BA-1201.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BA-1201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BA-1201.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BA-1201.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BB-1901.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BB-1901.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BB-1901.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BB-1901.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BC-2501.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BC-2501.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BC-2501.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BC-2501.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BE-3401.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BE-3401.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BE-3401.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BE-3401.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BF-3801.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BF-3801.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BF-3801.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BF-3801.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BG-4701.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BG-4701.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BG-4701.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BG-4701.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BH-5501.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BH-5501.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BH-5501.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BH-5501.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1BI-6201.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BI-6201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BI-6201.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BI-6201.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CA-1301.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CA-1301.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CA-1301.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CA-1301.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CB-0401.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CB-0401.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CB-0401.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CB-0401.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CC-2701.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CC-2701.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CC-2701.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CC-2701.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CD-2801.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CD-2801.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CD-2801.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CD-2801.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CE-0601.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CE-0601.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CE-0601.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CE-0601.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CF-3901.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CF-3901.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CF-3901.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CF-3901.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CG-4801.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CG-4801.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CG-4801.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CG-4801.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1CH-5601.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CH-5601.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CH-5601.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1CH-5601.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DA-1401.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DA-1401.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DA-1401.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DA-1401.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DB-2001.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DB-2001.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DB-2001.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DB-2001.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DD-2901.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DD-2901.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DD-2901.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DD-2901.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DE-0701.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DE-0701.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DE-0701.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DE-0701.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DF-4101.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DF-4101.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DF-4101.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DF-4101.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DG-4901.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DG-4901.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DG-4901.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DG-4901.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1DH-5701.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DH-5701.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DH-5701.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1DH-5701.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1EA-1501.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EA-1501.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EA-1501.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EA-1501.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1EB-2101.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EB-2101.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EB-2101.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EB-2101.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1ED-3001.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1ED-3001.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1ED-3001.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1ED-3001.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1EE-3501.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EE-3501.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EE-3501.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EE-3501.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1EF-4201.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EF-4201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EF-4201.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EF-4201.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1EG-5001.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EG-5001.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EG-5001.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EG-5001.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1EH-5801.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EH-5801.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EH-5801.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1EH-5801.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FA-1601.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FA-1601.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FA-1601.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FA-1601.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FB-2201.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FB-2201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FB-2201.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FB-2201.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FD-3101.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FD-3101.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FD-3101.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FD-3101.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FE-3601.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FE-3601.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FE-3601.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FE-3601.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FF-4301.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FF-4301.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FF-4301.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FF-4301.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FG-5101.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FG-5101.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FG-5101.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FG-5101.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1FH-5901.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FH-5901.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FH-5901.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FH-5901.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GA-1701.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GA-1701.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GA-1701.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GA-1701.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GB-0801.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GB-0801.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GB-0801.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GB-0801.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GD-3201.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GD-3201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GD-3201.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GD-3201.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GE-0901.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GE-0901.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GE-0901.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GE-0901.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GF-4401.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GF-4401.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GF-4401.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GF-4401.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GG-5201.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GG-5201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GG-5201.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GG-5201.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1GH-6001.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GH-6001.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GH-6001.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GH-6001.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1HB-2301.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HB-2301.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HB-2301.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HB-2301.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1HD-0501.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HD-0501.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HD-0501.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HD-0501.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1HE-3701.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HE-3701.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HE-3701.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HE-3701.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1HF-4501.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HF-4501.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HF-4501.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HF-4501.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1HG-5301.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HG-5301.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HG-5301.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HG-5301.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\1HH-6101.D\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HH-6101.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HH-6101.pdf
# Copied 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HH-6101.pdf
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0101.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0101.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0101.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0101.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0101.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0201.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0201.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0201.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0201.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0301.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0301.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0301.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0301.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-0301.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-2601.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-2601.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-2601.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-2601.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-2601.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-4001.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-4001.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-4001.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-4001.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_003-4001.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AA-1101.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AA-1101.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AA-1101.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AA-1101.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AA-1101.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AB-1801.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AB-1801.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AB-1801.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AB-1801.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AB-1801.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AC-2401.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AC-2401.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AC-2401.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AC-2401.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AC-2401.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AE-3301.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AE-3301.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AE-3301.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AE-3301.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AE-3301.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AG-4601.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AG-4601.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AG-4601.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AG-4601.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AG-4601.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AH-5401.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AH-5401.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AH-5401.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AH-5401.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AH-5401.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AI-1001.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AI-1001.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AI-1001.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AI-1001.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1AI-1001.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BA-1201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BA-1201.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BA-1201.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BA-1201.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BA-1201.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BB-1901.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BB-1901.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BB-1901.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BB-1901.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1BB-1901.pdf' are the same file
# ...
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FH-5901.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FH-5901.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FH-5901.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FH-5901.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1FH-5901.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GA-1701.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GA-1701.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GA-1701.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GA-1701.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GA-1701.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GB-0801.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GB-0801.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GB-0801.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GB-0801.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GB-0801.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GD-3201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GD-3201.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GD-3201.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GD-3201.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GD-3201.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GE-0901.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GE-0901.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GE-0901.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GE-0901.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GE-0901.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GF-4401.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GF-4401.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GF-4401.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GF-4401.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GF-4401.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GG-5201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GG-5201.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GG-5201.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GG-5201.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GG-5201.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GH-6001.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GH-6001.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GH-6001.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GH-6001.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1GH-6001.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HB-2301.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HB-2301.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HB-2301.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HB-2301.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HB-2301.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HD-0501.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HD-0501.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HD-0501.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HD-0501.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HD-0501.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HE-3701.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HE-3701.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HE-3701.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HE-3701.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HE-3701.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HF-4501.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HF-4501.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HF-4501.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HF-4501.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HF-4501.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HG-5301.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HG-5301.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HG-5301.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HG-5301.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HG-5301.pdf' are the same file
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HH-6101.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HH-6101.pdf
# Error copying 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HH-6101.pdf: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HH-6101.pdf' and '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 2\\SEC\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10_1HH-6101.pdf' are the same file
# Successfully copied 62 PDF files to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 2\SEC\2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10\All Reports 2024 06 18 TL1A ATTO AND NANO FC 2024-06-18 13-37-10

# %%
import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Normalize the path to handle long paths on Windows if not a network path
    if os.name == 'nt' and not main_directory.startswith('\\\\'):
        main_directory = os.path.abspath(main_directory)
        if not main_directory.startswith('\\\\?\\'):
            main_directory = '\\\\?\\' + main_directory
    
    # Debug: Print the main directory path
    print(f"Main directory: {main_directory}")
    
    # Get the name of the main directory
    main_dir_name = os.path.basename(main_directory)
    
    # Create the new folder name
    new_folder_name = f"All Reports {main_dir_name}"
    
    # Create the path for the new folder
    new_folder_path = os.path.join(main_directory, new_folder_name)
    
    # Debug: Print the new folder path
    print(f"New folder path: {new_folder_path}")
    
    # Create the new folder if it does not exist
    try:
        os.makedirs(new_folder_path, exist_ok=True)
        print(f"Created folder: {new_folder_path}")
    except OSError as e:
        print(f"Error creating folder: {new_folder_path} - {e}")
        return
    
    # Counter for successfully copied files
    copied_count = 0
    
    # Search for PDFs in subdirectories
    for root, dirs, files in os.walk(main_directory):
        for file in files:
            if file.endswith(".pdf"):
                # Source and destination paths
                src_path = os.path.join(root, file)
                dst_path = os.path.join(new_folder_path, file)
                
                # Debug: Print source and destination paths
                print(f"Copying from {src_path} to {dst_path}")
                
                try:
                    # Copy file
                    shutil.copy2(src_path, dst_path)
                    print(f"Copied {file}")
                    copied_count += 1
                except FileNotFoundError:
                    print(f"File {file} not found.")
                except Exception as e:
                    print(f"Error copying {file}: {e}")
    
    print(f"Successfully copied {copied_count} PDF files to {new_folder_path}")

# Example usage
main_directory = input("Enter the main directory path: ")
search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# Main directory: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# New folder path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# Created folder: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\003-0701.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_003-0701.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_003-0701.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_003-0701.pdf not found.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\008-0101.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0101.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0101.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0101.pdf not found.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\008-0201.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0201.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0201.pdf not found.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\008-0301.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0301.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0301.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0301.pdf not found.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\008-0601.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0601.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0601.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0601.pdf not found.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\1DG-0401.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_1DG-0401.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_1DG-0401.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_1DG-0401.pdf not found.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\1EG-0501.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_1EG-0501.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_1EG-0501.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_1EG-0501.pdf not found.
# Successfully copied 0 PDF files to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30

# %%
import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Normalize the path to handle long paths on Windows if not a network path
    if os.name == 'nt' and not main_directory.startswith('\\\\'):
        main_directory = os.path.abspath(main_directory)
        if not main_directory.startswith('\\\\?\\'):
            main_directory = '\\\\?\\' + main_directory
    
    # Debug: Print the main directory path
    print(f"Main directory: {main_directory}")
    
    # Get the name of the main directory
    main_dir_name = os.path.basename(main_directory)
    
    # Create the new folder name
    new_folder_name = f"All Reports {main_dir_name}"
    
    # Create the path for the new folder
    new_folder_path = os.path.join(main_directory, new_folder_name)
    
    # Debug: Print the new folder path
    print(f"New folder path: {new_folder_path}")
    
    # Create the new folder if it does not exist
    try:
        os.makedirs(new_folder_path, exist_ok=True)
        print(f"Created folder: {new_folder_path}")
    except OSError as e:
        print(f"Error creating folder: {new_folder_path} - {e}")
        return
    
    # Counter for successfully copied files
    copied_count = 0
    
    # Search for PDFs in subdirectories
    for root, dirs, files in os.walk(main_directory):
        for file in files:
            if file.endswith(".pdf"):
                # Source and destination paths
                src_path = os.path.join(root, file)
                dst_path = os.path.join(new_folder_path, file)
                
                # Debug: Print source and destination paths
                print(f"Copying from {src_path} to {dst_path}")
                
                try:
                    # Copy file
                    shutil.copy2(src_path, dst_path)
                    print(f"Copied {file}")
                    copied_count += 1
                except FileNotFoundError:
                    print(f"File {file} not found.")
                except Exception as e:
                    print(f"Error copying {file}: {e}")
    
    print(f"Successfully copied {copied_count} PDF files to {new_folder_path}")

# Example usage
main_directory = input("Enter the main directory path: ")
search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# Main directory: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# New folder path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# Error creating folder: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30 - [WinError 3] The system cannot find the path specified: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 1\\SEC\\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\All Reports All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30'

# %%
import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Normalize the path to handle long paths on Windows if not a network path
    if os.name == 'nt' and not main_directory.startswith('\\\\'):
        main_directory = os.path.abspath(main_directory)
        if not main_directory.startswith('\\\\?\\'):
            main_directory = '\\\\?\\' + main_directory
    
    # Debug: Print the main directory path
    print(f"Main directory: {main_directory}")
    
    # Get the name of the main directory
    main_dir_name = os.path.basename(main_directory)
    
    # Create the new folder name
    new_folder_name = f"All Reports {main_dir_name}"
    
    # Create the path for the new folder
    new_folder_path = os.path.join(main_directory, new_folder_name)
    
    # Debug: Print the new folder path
    print(f"New folder path: {new_folder_path}")
    
    # Create the new folder if it does not exist
    if not os.path.exists(new_folder_path):
        os.makedirs(new_folder_path)
    else:
        print(f"The folder '{new_folder_path}' already exists.")
    
    # Counter for successfully copied files
    copied_count = 0
    
    # Search for PDFs in subdirectories
    for root, dirs, files in os.walk(main_directory):
        for file in files:
            if file.endswith(".pdf"):
                # Source and destination paths
                src_path = os.path.join(root, file)
                dst_path = os.path.join(new_folder_path, file)
                
                # Debug: Print source and destination paths
                print(f"Copying from {src_path} to {dst_path}")
                
                try:
                    # Copy file
                    shutil.copy2(src_path, dst_path)
                    print(f"Copied {file}")
                    copied_count += 1
                except FileNotFoundError:
                    print(f"File {file} not found.")
                except Exception as e:
                    print(f"Error copying {file}: {e}")
    
    print(f"Successfully copied {copied_count} PDF files to {new_folder_path}")

# Example usage
main_directory = input("Enter the main directory path: ")
search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# Main directory: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# New folder path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 60
#      58 # Example usage
#      59 main_directory = input("Enter the main directory path: ")
# ---> 60 search_pdfs_and_create_folder(main_directory)
#
# Cell In[8], line 28, in search_pdfs_and_create_folder(main_directory)
#      26 # Create the new folder if it does not exist
#      27 if not os.path.exists(new_folder_path):
# ---> 28     os.makedirs(new_folder_path)
#      29 else:
#      30     print(f"The folder '{new_folder_path}' already exists.")
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 1\\SEC\\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\All Reports All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30'

# %%
import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Normalize the path to handle long paths on Windows if not a network path
    if os.name == 'nt' and not main_directory.startswith('\\\\'):
        main_directory = os.path.abspath(main_directory)
        if not main_directory.startswith('\\\\?\\'):
            main_directory = '\\\\?\\' + main_directory
    
    # Debug: Print the main directory path
    print(f"Main directory: {main_directory}")
    
    # Get the name of the main directory
    main_dir_name = os.path.basename(main_directory)
    
    # Create the new folder name
    new_folder_name = f"All Reports {main_dir_name}"
    
    # Create the path for the new folder
    new_folder_path = os.path.join(main_directory, new_folder_name)
    
    # Debug: Print the new folder path
    print(f"New folder path: {new_folder_path}")
    
    # Create the new folder if it does not exist
    if not os.path.exists(new_folder_path):
        os.makedirs(new_folder_path)
    else:
        print(f"The folder '{new_folder_path}' already exists.")
    
    # Counter for successfully copied files
    copied_count = 0
    
    # Search for PDFs in subdirectories
    for root, dirs, files in os.walk(main_directory):
        for file in files:
            if file.endswith(".pdf"):
                # Source and destination paths
                src_path = os.path.join(root, file)
                dst_path = os.path.join(new_folder_path, file)
                
                # Debug: Print source and destination paths
                print(f"Copying from {src_path} to {dst_path}")
                
                # Handle long paths for source and destination if not network paths
                if os.name == 'nt' and not (src_path.startswith('\\\\') or dst_path.startswith('\\\\')):
                    if not src_path.startswith('\\\\?\\'):
                        src_path = '\\\\?\\' + os.path.abspath(src_path)
                    if not dst_path.startswith('\\\\?\\'):
                        dst_path = '\\\\?\\' + os.path.abspath(dst_path)
                
                try:
                    shutil.copy2(src_path, dst_path)
                    print(f"Copied {file}")
                    copied_count += 1
                except FileNotFoundError:
                    print(f"File {file} not found.")
    
    print(f"Successfully copied {copied_count} PDF files to {new_folder_path}")

# Example usage
main_directory = input("Enter the main directory path: ")
search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# Main directory: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# New folder path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 64
#      62 # Example usage
#      63 main_directory = input("Enter the main directory path: ")
# ---> 64 search_pdfs_and_create_folder(main_directory)
#
# Cell In[7], line 28, in search_pdfs_and_create_folder(main_directory)
#      26 # Create the new folder if it does not exist
#      27 if not os.path.exists(new_folder_path):
# ---> 28     os.makedirs(new_folder_path)
#      29 else:
#      30     print(f"The folder '{new_folder_path}' already exists.")
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 1\\SEC\\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\All Reports All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30'

# %%
import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Normalize the path to handle long paths on Windows if not a network path
    if os.name == 'nt' and not main_directory.startswith('\\\\'):
        main_directory = os.path.abspath(main_directory)
        if not main_directory.startswith('\\\\?\\'):
            main_directory = '\\\\?\\' + main_directory
    
    # Debug: Print the main directory path
    print(f"Main directory: {main_directory}")
    
    # Get the name of the main directory
    main_dir_name = os.path.basename(main_directory)
    
    # Create the new folder name
    new_folder_name = f"All Reports {main_dir_name}"
    
    # Create the path for the new folder
    new_folder_path = os.path.join(main_directory, new_folder_name)
    
    # Debug: Print the new folder path
    print(f"New folder path: {new_folder_path}")
    
    # Create the new folder if it does not exist
    if not os.path.exists(new_folder_path):
        os.makedirs(new_folder_path)
    else:
        print(f"The folder '{new_folder_path}' already exists.")
    
    # Search for PDFs in subdirectories
    for root, dirs, files in os.walk(main_directory):
        for file in files:
            if file.endswith(".pdf"):
                # Source and destination paths
                src_path = os.path.join(root, file)
                dst_path = os.path.join(new_folder_path, file)
                
                # Debug: Print source and destination paths
                print(f"Copying from {src_path} to {dst_path}")
                
                # Handle long paths for source and destination if not network paths
                if os.name == 'nt' and not (src_path.startswith('\\\\') or dst_path.startswith('\\\\')):
                    if not src_path.startswith('\\\\?\\'):
                        src_path = '\\\\?\\' + os.path.abspath(src_path)
                    if not dst_path.startswith('\\\\?\\'):
                        dst_path = '\\\\?\\' + os.path.abspath(dst_path)
                
                try:
                    shutil.copy2(src_path, dst_path)
                    print(f"Copied {file}")
                except FileNotFoundError:
                    print(f"File {file} not found.")
    
    print(f"All PDF files have been copied to {new_folder_path}")

# Example usage
main_directory = input("Enter the main directory path: ")
search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# Main directory: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# New folder path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# The folder '\\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30' already exists.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\003-0701.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_003-0701.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_003-0701.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_003-0701.pdf not found.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\008-0101.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0101.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0101.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0101.pdf not found.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\008-0201.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0201.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0201.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0201.pdf not found.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\008-0301.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0301.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0301.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0301.pdf not found.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\008-0601.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0601.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0601.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_008-0601.pdf not found.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\1DG-0401.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_1DG-0401.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_1DG-0401.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_1DG-0401.pdf not found.
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\1EG-0501.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_1EG-0501.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_1EG-0501.pdf
# File 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_1EG-0501.pdf not found.
# All PDF files have been copied to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30

# %%
import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Normalize the path to handle long paths on Windows if not a network path
    if os.name == 'nt' and not main_directory.startswith('\\\\'):
        main_directory = os.path.abspath(main_directory)
        if not main_directory.startswith('\\\\?\\'):
            main_directory = '\\\\?\\' + main_directory
    
    # Debug: Print the main directory path
    print(f"Main directory: {main_directory}")
    
    # Get the name of the main directory
    main_dir_name = os.path.basename(main_directory)
    
    # Create the new folder name
    new_folder_name = f"All Reports {main_dir_name}"
    
    # Create the path for the new folder
    new_folder_path = os.path.join(main_directory, new_folder_name)
    
    # Debug: Print the new folder path
    print(f"New folder path: {new_folder_path}")
    
    # Create the new folder and exit if it already contains files
    if os.path.exists(new_folder_path) and os.listdir(new_folder_path):
        print(f"The folder '{new_folder_path}' already exists and contains files. Exiting.")
        return
    else:
        os.makedirs(new_folder_path, exist_ok=True)
    
    # Search for PDFs in subdirectories
    for root, dirs, files in os.walk(main_directory):
        for file in files:
            if file.endswith(".pdf"):
                # Copy PDF files to the new folder
                src_path = os.path.join(root, file)
                dst_path = os.path.join(new_folder_path, file)
                
                # Debug: Print source and destination paths
                print(f"Copying from {src_path} to {dst_path}")
                
                # Handle long paths for source and destination if not network paths
                if os.name == 'nt' and not (src_path.startswith('\\\\') or dst_path.startswith('\\\\')):
                    if not src_path.startswith('\\\\?\\'):
                        src_path = '\\\\?\\' + os.path.abspath(src_path)
                    if not dst_path.startswith('\\\\?\\'):
                        dst_path = '\\\\?\\' + os.path.abspath(dst_path)
                
                shutil.copy2(src_path, dst_path)
    
    print(f"All PDF files have been copied to {new_folder_path}")

# Example usage
main_directory = input("Enter the main directory path: ")
search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# Main directory: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# New folder path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# Copying from \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\003-0701.D\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_003-0701.pdf to \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_003-0701.pdf
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 57
#      55 # Example usage
#      56 main_directory = input("Enter the main directory path: ")
# ---> 57 search_pdfs_and_create_folder(main_directory)
#
# Cell In[5], line 51, in search_pdfs_and_create_folder(main_directory)
#      48                 if not dst_path.startswith('\\\\?\\'):
#      49                     dst_path = '\\\\?\\' + os.path.abspath(dst_path)
# ---> 51             shutil.copy2(src_path, dst_path)
#      53 print(f"All PDF files have been copied to {new_folder_path}")
#
# File ~\anaconda3\Lib\shutil.py:436, in copy2(src, dst, follow_symlinks)
#     434 if os.path.isdir(dst):
#     435     dst = os.path.join(dst, os.path.basename(src))
# --> 436 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     437 copystat(src, dst, follow_symlinks=follow_symlinks)
#     438 return dst
#
# File ~\anaconda3\Lib\shutil.py:258, in copyfile(src, dst, follow_symlinks)
#     256 with open(src, 'rb') as fsrc:
#     257     try:
# --> 258         with open(dst, 'wb') as fdst:
#     259             # macOS
#     260             if _HAS_FCOPYFILE:
#     261                 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 1\\SEC\\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_003-0701.pdf'

# %%
import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Normalize the path to handle long paths on Windows
    if os.name == 'nt':
        main_directory = os.path.abspath(main_directory)
        if not main_directory.startswith('\\\\?\\'):
            main_directory = '\\\\?\\' + main_directory
    
    # Get the name of the main directory
    main_dir_name = os.path.basename(main_directory)
    
    # Create the new folder name
    new_folder_name = f"All Reports {main_dir_name}"
    
    # Create the path for the new folder
    new_folder_path = os.path.join(main_directory, new_folder_name)
    
    # Create the new folder and exit if it already contains files
    if os.path.exists(new_folder_path) and os.listdir(new_folder_path):
        print(f"The folder '{new_folder_path}' already exists and contains files. Exiting.")
        return
    else:
        os.makedirs(new_folder_path, exist_ok=True)
    
    # Search for PDFs in subdirectories
    for root, dirs, files in os.walk(main_directory):
        for file in files:
            if file.endswith(".pdf"):
                # Copy PDF files to the new folder
                src_path = os.path.join(root, file)
                dst_path = os.path.join(new_folder_path, file)
                
                # Handle long paths for source and destination
                if os.name == 'nt':
                    if not src_path.startswith('\\\\?\\'):
                        src_path = '\\\\?\\' + os.path.abspath(src_path)
                    if not dst_path.startswith('\\\\?\\'):
                        dst_path = '\\\\?\\' + os.path.abspath(dst_path)
                
                shutil.copy2(src_path, dst_path)
    
    print(f"All PDF files have been copied to {new_folder_path}")

# Example usage
main_directory = input("Enter the main directory path: ")
search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 48
#      46 # Example usage
#      47 main_directory = input("Enter the main directory path: ")
# ---> 48 search_pdfs_and_create_folder(main_directory)
#
# Cell In[4], line 25, in search_pdfs_and_create_folder(main_directory)
#      23     return
#      24 else:
# ---> 25     os.makedirs(new_folder_path, exist_ok=True)
#      27 # Search for PDFs in subdirectories
#      28 for root, dirs, files in os.walk(main_directory):
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
#     [... skipping similar frames: makedirs at line 215 (4 times)]
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: '\\\\?\\\\\\'

# %%
import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Get the name of the main directory
    main_dir_name = os.path.basename(main_directory)
    
    # Create the new folder name
    new_folder_name = f"All Reports {main_dir_name}"
    
    # Create the path for the new folder
    new_folder_path = os.path.join(main_directory, new_folder_name)
    
    # Create the new folder and exit if it already contains files
    if os.path.exists(new_folder_path) and os.listdir(new_folder_path):
        print(f"The folder '{new_folder_path}' already exists and contains files. Exiting.")
        return
    else:
        os.makedirs(new_folder_path, exist_ok=True)
    
    # Search for PDFs in subdirectories
    for root, dirs, files in os.walk(main_directory):
        for file in files:
            if file.endswith(".pdf"):
                # Copy PDF files to the new folder
                shutil.copy2(os.path.join(root, file), new_folder_path)
    
    print(f"All PDF files have been copied to {new_folder_path}")

# Example usage
main_directory = input("Enter the main directory path: ")
search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 32
#      30 # Example usage
#      31 main_directory = input("Enter the main directory path: ")
# ---> 32 search_pdfs_and_create_folder(main_directory)
#
# Cell In[3], line 26, in search_pdfs_and_create_folder(main_directory)
#      23     for file in files:
#      24         if file.endswith(".pdf"):
#      25             # Copy PDF files to the new folder
# ---> 26             shutil.copy2(os.path.join(root, file), new_folder_path)
#      28 print(f"All PDF files have been copied to {new_folder_path}")
#
# File ~\anaconda3\Lib\shutil.py:436, in copy2(src, dst, follow_symlinks)
#     434 if os.path.isdir(dst):
#     435     dst = os.path.join(dst, os.path.basename(src))
# --> 436 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     437 copystat(src, dst, follow_symlinks=follow_symlinks)
#     438 return dst
#
# File ~\anaconda3\Lib\shutil.py:258, in copyfile(src, dst, follow_symlinks)
#     256 with open(src, 'rb') as fsrc:
#     257     try:
# --> 258         with open(dst, 'wb') as fdst:
#     259             # macOS
#     260             if _HAS_FCOPYFILE:
#     261                 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 1\\SEC\\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_003-0701.pdf'

# %%
import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Check if the provided directory exists
    if not os.path.exists(main_directory):
        print(f"The directory '{main_directory}' does not exist.")
        return

    # Get the name of the main directory
    main_dir_name = os.path.basename(main_directory)
    
    # Create the new folder name
    new_folder_name = f"All Reports {main_dir_name}"
    
    # Create the path for the new folder
    new_folder_path = os.path.join(main_directory, new_folder_name)
    
    # Create the new folder
    os.makedirs(new_folder_path, exist_ok=True)
    
    # Search for PDFs in subdirectories
    for root, dirs, files in os.walk(main_directory):
        for file in files:
            if file.endswith(".pdf"):
                # Copy PDF files to the new folder
                shutil.copy2(os.path.join(root, file), new_folder_path)
    
    print(f"All PDF files have been copied to {new_folder_path}")

# Example usage
main_directory = input("Enter the main directory path: ")
search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 33
#      31 # Example usage
#      32 main_directory = input("Enter the main directory path: ")
# ---> 33 search_pdfs_and_create_folder(main_directory)
#
# Cell In[2], line 27, in search_pdfs_and_create_folder(main_directory)
#      24     for file in files:
#      25         if file.endswith(".pdf"):
#      26             # Copy PDF files to the new folder
# ---> 27             shutil.copy2(os.path.join(root, file), new_folder_path)
#      29 print(f"All PDF files have been copied to {new_folder_path}")
#
# File ~\anaconda3\Lib\shutil.py:436, in copy2(src, dst, follow_symlinks)
#     434 if os.path.isdir(dst):
#     435     dst = os.path.join(dst, os.path.basename(src))
# --> 436 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     437 copystat(src, dst, follow_symlinks=follow_symlinks)
#     438 return dst
#
# File ~\anaconda3\Lib\shutil.py:258, in copyfile(src, dst, follow_symlinks)
#     256 with open(src, 'rb') as fsrc:
#     257     try:
# --> 258         with open(dst, 'wb') as fdst:
#     259             # macOS
#     260             if _HAS_FCOPYFILE:
#     261                 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 1\\SEC\\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_003-0701.pdf'

# %%
# v0.1

import os
import shutil

def search_pdfs_and_create_folder(main_directory):
    # Get the name of the main directory
    main_dir_name = os.path.basename(main_directory)
    
    # Create the new folder name
    new_folder_name = f"All Reports {main_dir_name}"
    
    # Create the path for the new folder
    new_folder_path = os.path.join(main_directory, new_folder_name)
    
    # Create the new folder
    os.makedirs(new_folder_path, exist_ok=True)
    
    # Search for PDFs in subdirectories
    for root, dirs, files in os.walk(main_directory):
        for file in files:
            if file.endswith(".pdf"):
                # Copy PDF files to the new folder
                shutil.copy2(os.path.join(root, file), new_folder_path)
    
    print(f"All PDF files have been copied to {new_folder_path}")

# Example usage
main_directory = input("Enter the main directory path: ")
search_pdfs_and_create_folder(main_directory)
# Out:
# Enter the main directory path: \\10.2.20.249\Lab Data\Joel Tencer\Agilent HPLC 1\SEC\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 30
#      28 # Example usage
#      29 main_directory = input("Enter the main directory path: ")
# ---> 30 search_pdfs_and_create_folder(main_directory)
#
# Cell In[1], line 24, in search_pdfs_and_create_folder(main_directory)
#      21     for file in files:
#      22         if file.endswith(".pdf"):
#      23             # Copy PDF files to the new folder
# ---> 24             shutil.copy2(os.path.join(root, file), new_folder_path)
#      26 print(f"All PDF files have been copied to {new_folder_path}")
#
# File ~\anaconda3\Lib\shutil.py:436, in copy2(src, dst, follow_symlinks)
#     434 if os.path.isdir(dst):
#     435     dst = os.path.join(dst, os.path.basename(src))
# --> 436 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     437 copystat(src, dst, follow_symlinks=follow_symlinks)
#     438 return dst
#
# File ~\anaconda3\Lib\shutil.py:258, in copyfile(src, dst, follow_symlinks)
#     256 with open(src, 'rb') as fsrc:
#     257     try:
# --> 258         with open(dst, 'wb') as fdst:
#     259             # macOS
#     260             if _HAS_FCOPYFILE:
#     261                 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\\\10.2.20.249\\Lab Data\\Joel Tencer\\Agilent HPLC 1\\SEC\\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\All Reports 2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30\\2024 07 01 ATTO-002 IL-13 WBP71243 37 39 2024-07-01 17-17-30_003-0701.pdf'
